# %%
age_list = [24, 25, 27, 28, 29]
name_list = ["Anand", "Bala", "Chandru", "Divya", "Karthika"]

print("Initial age_list:", age_list)
print("Initial name_list:", name_list)
# Out:
# Initial age_list: [24, 25, 27, 28, 29]
# Initial name_list: ['Anand', 'Bala', 'Chandru', 'Divya', 'Karthika']

# %%
name_list.append("Yazhini")
print("Initial name_list:", name_list)
# Out:
# Initial name_list: ['Anand', 'Bala', 'Chandru', 'Divya', 'Karthika', 'Yazhini', 'Yazhini', 'Yazhini']

# %%
age_list.insert(2, 26)
print("Initial age_list:", age_list)
# Out:
# Initial age_list: [24, 25, 26, 26, 27, 28, 29]

# %%
name_list.remove("Yazhini")
print("Initial name_list:", name_list)
# Out:
# Initial name_list: ['Anand', 'Bala', 'Chandru', 'Divya', 'Karthika', 'Yazhini']

# %%
age_list.pop()
print(age_list)
# Out:
# [24, 25, 26, 26, 27, 28]

# %%
age_list.extend([31, 30, 32])
print(age_list)
# Out:
# [24, 25, 26, 26, 27, 28, 31, 30, 32]

# %%
age_list.sort(reverse=True)
print(age_list)
# Out:
# [32, 31, 30, 28, 27, 26, 26, 25, 24]

# %%
max_age = max(age_list)
min_age = min(age_list)
total_age = sum(age_list)
print("\nModified age_list (Sorted Descending):", age_list)
print("Modified name_list:", name_list)
print("Max Age: %d, Min Age: %d, Sum of Ages: %d" % (max_age, min_age, total_age))
# Out:
# Modified age_list (Sorted Descending): [32, 31, 30, 28, 27, 26, 26, 25, 24]
# Modified name_list: ['Anand', 'Bala', 'Chandru', 'Divya', 'Karthika', 'Yazhini']
# Max Age: 32, Min Age: 24, Sum of Ages: 249

# %%
student_marks = {
    "Arun": 85,
    "Bala": 92,
    "Chitra": 78,
    "Divya": 88,
    "Ezhil": 95
}
print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 92, 'Chitra': 78, 'Divya': 88, 'Ezhil': 95}

# %%
print("Mark of Bala:", student_marks["Bala"])
# Out:
# Mark of Bala: 92

# %%
student_marks["Janani"] = 80

student_marks["Chitra"] = 82

print(student_marks)
# Out:
# {'Arun': 85, 'Bala': 92, 'Chitra': 82, 'Divya': 88, 'Ezhil': 95, 'Janani': 80}

# %%
print("\nAll Keys:", list(student_marks.keys()))
print("All Values:", list(student_marks.values()))
print("All Key-Value Pairs:")
for student, mark in student_marks.items():
    print(f"  {student}: {mark}")
# Out:
# All Keys: ['Arun', 'Bala', 'Chitra', 'Divya', 'Ezhil', 'Janani']
# All Values: [85, 92, 82, 88, 95, 80]
# All Key-Value Pairs:
#   Arun: 85
#   Bala: 92
#   Chitra: 82
#   Divya: 88
#   Ezhil: 95
#   Janani: 80

# %%
my_set = set(['a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'])
print("my_set output:", my_set)
# Out:
# my_set output: {'i', 'u', 'a', 'o', 'e'}

# %%
score = float(input("Enter your score (0 to 10): "))
# Out:
# Enter your score (0 to 10): 5

# %%
score = float(input("Enter your score (0 to 10): "))

if 0 <= score <= 10:
    if score > 7:
        print("Above Average: Outstanding performance! Keep up the excellent work.")
    elif 4 <= score <= 7:
        print("Average: Good effort! Keep practicing, there's room for improvement.")
    else:
        print("Below Average: Need to improve your performance; consistent practice will lead to better results.")
else:
    print("Invalid Input: Please enter a score between 0 and 10.")
# Out:
# Enter your score (0 to 10): 7
# Average: Good effort! Keep practicing, there's room for improvement.
